# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('general_data.csv', index_col = 'EmployeeID')

# %%
data
# Out:
#             Age Attrition     BusinessTravel              Department  \
# EmployeeID
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
# ...         ...       ...                ...                     ...
# 4406         42        No      Travel_Rarely  Research & Development
# 4407         29        No      Travel_Rarely  Research & Development
# 4408         25        No      Travel_Rarely  Research & Development
# 4409         42        No      Travel_Rarely                   Sales
# 4410         40        No      Travel_Rarely  Research & Development
#
#             DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# EmployeeID
# ...

# %%
data1 = pd.read_excel('data_dictionary.xlsx')
data1
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %%
data.shape
# Out:
# (4410, 23)

# %%
data['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
data.isnull()
# Out:
#               Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# EmployeeID
# 1           False      False           False       False             False
# 2           False      False           False       False             False
# 3           False      False           False       False             False
# 4           False      False           False       False             False
# 5           False      False           False       False             False
# ...           ...        ...             ...         ...               ...
# 4406        False      False           False       False             False
# 4407        False      False           False       False             False
# 4408        False      False           False       False             False
# 4409        False      False           False       False             False
# 4410        False      False           False       False             False
#
# ...

# %%
data.duplicated()
# Out:
# EmployeeID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 4406     True
# 4407     True
# 4408     True
# 4409     True
# 4410    False
# Length: 4410, dtype: bool

# %%
data.drop_duplicates()
# Out:
#             Age Attrition     BusinessTravel              Department  \
# EmployeeID
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
# ...         ...       ...                ...                     ...
# 3819         28       Yes      Travel_Rarely         Human Resources
# 3911         41        No         Non-Travel                   Sales
# 4227         36        No      Travel_Rarely  Research & Development
# 4396         40        No      Travel_Rarely  Research & Development
# 4410         40        No      Travel_Rarely  Research & Development
#
#             DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# EmployeeID
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
des_data =data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].describe()

# %%
des_data
# Out:
#                Age  DistanceFromHome  MonthlyIncome  YearsWithCurrManager  \
# count  4410.000000       4410.000000    4410.000000           4410.000000
# mean     36.923810          9.192517   65029.312925              4.123129
# std       9.133301          8.105026   47068.888559              3.567327
# min      18.000000          1.000000   10090.000000              0.000000
# 25%      30.000000          2.000000   29110.000000              2.000000
# 50%      36.000000          7.000000   49190.000000              3.000000
# 75%      43.000000         14.000000   83800.000000              7.000000
# max      60.000000         29.000000  199990.000000             17.000000
#
#        NumCompaniesWorked  PercentSalaryHike    Education  TotalWorkingYears  \
# count         4391.000000        4410.000000  4410.000000        4401.000000
# mean             2.694830          15.209524     2.912925          11.279936
# ...

# %%
median_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].median()
mode_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].mode()
std_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].std()
skew_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].skew()
kurt_data =data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].kurt()
var_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].var()
mean_data = data[['Age','DistanceFromHome','MonthlyIncome','YearsWithCurrManager','NumCompaniesWorked','PercentSalaryHike','Education','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager','NumCompaniesWorked',]].mean()

# %%
print(' Median of each numeric column =')
print('  ')
print(median_data)
print(' ')
print(' Mean = ')
print('  ')
print(mean_data)
# Out:
#  Median of each numeric column =
#
# Age                           36.0
# DistanceFromHome               7.0
# MonthlyIncome              49190.0
# YearsWithCurrManager           3.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# Education                      3.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# NumCompaniesWorked             2.0
# dtype: float64
#
#  Mean =
#
# Age                           36.923810
# DistanceFromHome               9.192517
# MonthlyIncome              65029.312925
# YearsWithCurrManager           4.123129
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# Education                      2.912925
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# ...

# %%
plt.boxplot(data.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eee627aa08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eee6340fc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eedd9ad1c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eee51927c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eee482adc8>],
#  'means': []}

# %% [markdown]
# ## From above: We can see that the 'Age' has almost same values for mean and median, thus no outliers. We can double check that with the boxplot above!!
#
# ## But below we see for the boxplot of 'Monthly Income' ,there are several 'outliers'. This was hinted very accurately by the wide difference in the mean and median value of 'Monthly income'.

# %%
 plt.boxplot(data.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eee6039508>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eee627a548>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eee60d9408>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eee6255748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eee643a488>],
#  'means': []}

# %%
plt.boxplot(data.PercentSalaryHike)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eee60bde88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eee6097888>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eee60987c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eee60ac788>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eee6115448>],
#  'means': []}

# %%
plt.boxplot(data.YearsAtCompany)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eee67e7208>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1eee5153588>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1eee66b09c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eee680c2c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eee623a448>],
#  'means': []}

# %%
skew_data
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# MonthlyIncome              1.368884
# YearsWithCurrManager       0.832884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# Education                 -0.289484
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# NumCompaniesWorked         1.026767
# dtype: float64

# %%
kurt_data
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# MonthlyIncome              1.000232
# YearsWithCurrManager       0.167949
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# Education                 -0.560569
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# NumCompaniesWorked         0.007287
# dtype: float64

# %% [markdown]
# ## from the kurt_data above, we can infer that only for 'education' koutosis is most negative, i.e flat!! with the highest peak found for 'Years since last promotion' and 'Years at company'.
#
# ## from the skew_data, we see 'Education' is the only one haveing a negative skewness, i.e median(3)>mean(2.9), telling us most of the employee are 'Bachelors'.

# %%
std_data
# Out:
# Age                            9.133301
# DistanceFromHome               8.105026
# MonthlyIncome              47068.888559
# YearsWithCurrManager           3.567327
# NumCompaniesWorked             2.498887
# PercentSalaryHike              3.659108
# Education                      1.023933
# TotalWorkingYears              7.782222
# TrainingTimesLastYear          1.288978
# YearsAtCompany                 6.125135
# YearsSinceLastPromotion        3.221699
# YearsWithCurrManager           3.567327
# NumCompaniesWorked             2.498887
# dtype: float64

# %% [markdown]
# ## Again from above,the standard deviation value is very very large for 'Monthly income', justifying the existence of 'outliers'. The most consistence variable here is 'Education', as it has the least standard deviation value.

# %%
mode_data
# Out:
#    Age  DistanceFromHome  MonthlyIncome  YearsWithCurrManager  \
# 0   35                 2          23420                     2
#
#    NumCompaniesWorked  PercentSalaryHike  Education  TotalWorkingYears  \
# 0                 1.0                 11          3               10.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      2               5                        0
#
#    YearsWithCurrManager  NumCompaniesWorked
# 0                     2                 1.0

# %% [markdown]
# # from the mode values above, we see:
#
# ## the majority of people earn Rs. 23420, but the mean we got was Rs. 65029.312 = wide gap telling some sort of discrimination on the payment grade.
#
# ## most people working here have 'Bachelors' degree, confirmed by the most consistant variable of 'Education'.
